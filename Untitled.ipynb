# %%
import pandas as pd
dataframe = pd.read_csv('yellow_tripdata_2016-01.csv')
dataframe.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:00   2016-01-01 00:00:00                2
# 1         2  2016-01-01 00:00:00   2016-01-01 00:00:00                5
# 2         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 3         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 4         2  2016-01-01 00:00:00   2016-01-01 00:00:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.10        -73.990372        40.734695           1
# 1           4.90        -73.980782        40.729912           1
# 2          10.54        -73.984550        40.679565           1
# 3           4.75        -73.993469        40.718990           1
# 4           1.76        -73.960625        40.781330           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
dataframe.iloc[200:230]
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 200         1  2016-01-29 09:18:23   2016-01-29 09:23:47                1
# 201         1  2016-01-29 09:18:23   2016-01-29 09:32:05                1
# 202         2  2016-01-29 09:18:23   2016-01-29 09:44:52                1
# 203         2  2016-01-29 09:18:23   2016-01-29 09:23:09                5
# 204         2  2016-01-29 09:18:23   2016-01-29 09:19:37                6
# 205         2  2016-01-29 09:18:23   2016-01-29 09:32:15                2
# 206         2  2016-01-29 09:18:23   2016-01-29 09:21:34                2
# 207         2  2016-01-29 09:18:24   2016-01-29 09:22:37                1
# 208         2  2016-01-29 09:18:24   2016-01-29 09:35:43                1
# 209         2  2016-01-29 09:18:24   2016-01-29 09:29:51                1
# 210         1  2016-01-29 09:18:25   2016-01-29 09:40:03                1
# 211         1  2016-01-29 09:18:25   2016-01-29 09:29:35                1
# ...

# %%
dataframe[dataframe['tolls_amount'] != 0.0].head(10
                                                )
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 84          1  2016-01-01 00:00:56   2016-01-01 00:17:24                1
# 88          2  2016-01-01 00:01:01   2016-01-01 00:13:08                6
# 108         1  2016-01-01 00:01:14   2016-01-01 00:38:19                1
# 253         1  2016-01-29 09:18:31   2016-01-29 09:45:17                1
# 254         1  2016-01-29 09:18:31   2016-01-29 09:51:40                1
# 255         2  2016-01-29 09:18:31   2016-01-29 09:40:50                6
# 268         2  2016-01-29 09:18:33   2016-01-29 09:40:10                1
# 289         1  2016-01-29 09:18:37   2016-01-29 09:56:54                1
# 302         1  2016-01-29 09:18:39   2016-01-29 09:53:16                1
# 388         2  2016-01-29 09:18:54   2016-01-29 10:08:47                2
#
#      trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 84            5.70        -73.987724        40.750568           1
# ...

# %%
print('Maximum:', dataframe['fare_amount'].max())
print('Minimum:', dataframe['fare_amount'].min())
print('Mean:', dataframe['fare_amount'].mean())
print('Sum:', dataframe['fare_amount'].sum())
print('Count:', dataframe['fare_amount'].count())
# Out:
# Maximum: 111270.85
# Minimum: -957.6
# Mean: 12.486929470430434
# Sum: 136193166.58999994
# Count: 10906858

# %%
dataframe['store_and_fwd_flag'].value_counts()
# Out:
# store_and_fwd_flag
# N    10843625
# Y       63233
# Name: count, dtype: int64

# %%
dataframe['store_and_fwd_flag'].nunique()
# Out:
# 2

# %%
dataframe[dataframe['passenger_count'].isnull()].head(2)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, pickup_longitude, pickup_latitude, RatecodeID, store_and_fwd_flag, dropoff_longitude, dropoff_latitude, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount]
# Index: []

# %%
if dataframe.isnull().values.any():
    print("The DataFrame contains missing values.")
else:
    print("The DataFrame does not contain missing values.")
# Out:
# The DataFrame does not contain missing values.

# %%
dataframe.drop_duplicates().head(2)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:00   2016-01-01 00:00:00                2
# 1         2  2016-01-01 00:00:00   2016-01-01 00:00:00                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0            1.1        -73.990372        40.734695           1
# 1            4.9        -73.980782        40.729912           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.981842         40.732407             2
# 1                  N         -73.944473         40.716679             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          7.5    0.5      0.5         0.0           0.0
# 1         18.0    0.5      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3           8.8
# 1                    0.3          19.3

# %%
print("Number Of Rows In The Original DataFrame:", len(dataframe))
print("Number Of Rows After Deduping:", len(dataframe.drop_duplicates()))
# Out:
# Number Of Rows In The Original DataFrame: 10906858
# Number Of Rows After Deduping: 10906857

# %%
dataframe.groupby('payment_type').count()
